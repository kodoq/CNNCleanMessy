# %%
import tensorflow as tf

# %%
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pemula_academy/messy-vs-clean-room.zip \
  -O /tmp/messy_vs_clean_room.zip
# Out:
# --2022-08-30 08:52:17--  https://github.com/dicodingacademy/assets/raw/main/ml_pemula_academy/messy-vs-clean-room.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pemula_academy/messy-vs-clean-room.zip [following]
# --2022-08-30 08:52:17--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pemula_academy/messy-vs-clean-room.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70392746 (67M) [application/zip]
# Saving to: ‘/tmp/messy_vs_clean_room.zip’
#
# /tmp/messy_vs_clean 100%[===================>]  67.13M   319MB/s    in 0.2s
#
# 2022-08-30 08:52:17 (319 MB/s) - ‘/tmp/messy_vs_clean_room.zip’ saved [70392746/70392746]

# %%
# melakukan ekstraksi pada file zip
import zipfile,os
local_zip = '/tmp/messy_vs_clean_room.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

base_dir = '/tmp/images'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')

# %%
os.listdir('/tmp/images/train')
# Out:
# ['messy', 'clean']

# %%
os.listdir('/tmp/images/val')
# Out:
# ['messy', 'clean']

# %%
# membuat direktori ruangan rapi pada direktori data training
#train_clean_dir = os.path.join(train_dir, 'clean')

# membuat direktori ruangan berantakan pada direktori data training
#train_messy_dir = os.path.join(train_dir, 'messy')

# membuat direktori ruangan rapi pada direktori data validasi
#validation_clean_dir = os.path.join(validation_dir, 'clean')

# membuat direktori ruangan berantakan pada direktori data validasi
#validation_messy_dir = os.path.join(validation_dir, 'messy')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest')

validation_datagen = ImageDataGenerator(
                    rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,  # direktori data latih
        target_size=(150, 150),  # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=4,
        # karena ini merupakan masalah klasifikasi 2 kelas maka menggunakan class_mode = 'binary'
        class_mode='binary')

validation_generator = validation_datagen.flow_from_directory(
        validation_dir, # direktori data validasi
        target_size=(150, 150), # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=4, 
        # karena ini merupakan masalah klasifikasi 2 kelas maka menggunakan class_mode = 'binary'
        class_mode='binary')
# Out:
# Found 192 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(512, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 512)       590336
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 13,529,665
# Trainable params: 13,529,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer=tf.optimizers.Adam(),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=25,  # berapa batch yang akan dieksekusi pada setiap epoch
      epochs=25,
      validation_data=validation_generator, # menampilkan akurasi pengujian data validasi
      validation_steps=5,  # berapa batch yang akan dieksekusi pada setiap epoch
      verbose=2)
# Out:
# Epoch 1/25
# 25/25 - 14s - loss: 0.9132 - accuracy: 0.4800 - val_loss: 0.6921 - val_accuracy: 0.5000 - 14s/epoch - 568ms/step
# Epoch 2/25
# 25/25 - 1s - loss: 0.6968 - accuracy: 0.4600 - val_loss: 0.6931 - val_accuracy: 0.5000 - 987ms/epoch - 39ms/step
# Epoch 3/25
# 25/25 - 1s - loss: 0.6931 - accuracy: 0.5400 - val_loss: 0.6931 - val_accuracy: 0.5000 - 952ms/epoch - 38ms/step
# Epoch 4/25
# 25/25 - 1s - loss: 0.6933 - accuracy: 0.4500 - val_loss: 0.6931 - val_accuracy: 0.5000 - 976ms/epoch - 39ms/step
# Epoch 5/25
# 25/25 - 1s - loss: 0.6930 - accuracy: 0.4900 - val_loss: 0.6930 - val_accuracy: 0.5000 - 954ms/epoch - 38ms/step
# Epoch 6/25
# 25/25 - 1s - loss: 0.6923 - accuracy: 0.5600 - val_loss: 0.6924 - val_accuracy: 0.5000 - 950ms/epoch - 38ms/step
# Epoch 7/25
# 25/25 - 1s - loss: 0.6909 - accuracy: 0.5600 - val_loss: 0.6874 - val_accuracy: 0.5000 - 953ms/epoch - 38ms/step
# Epoch 8/25
# 25/25 - 1s - loss: 0.6860 - accuracy: 0.5100 - val_loss: 0.6573 - val_accuracy: 0.7000 - 1s/epoch - 49ms/step
# Epoch 9/25
# 25/25 - 1s - loss: 0.7159 - accuracy: 0.5500 - val_loss: 0.6911 - val_accuracy: 0.4500 - 1s/epoch - 49ms/step
# Epoch 10/25
# 25/25 - 1s - loss: 0.6932 - accuracy: 0.4800 - val_loss: 0.6913 - val_accuracy: 0.7500 - 1s/epoch - 48ms/step
# Epoch 11/25
# 25/25 - 1s - loss: 0.6855 - accuracy: 0.6500 - val_loss: 0.6578 - val_accuracy: 0.5500 - 962ms/epoch - 38ms/step
# Epoch 12/25
# 25/25 - 1s - loss: 0.6757 - accuracy: 0.6400 - val_loss: 0.5786 - val_accuracy: 0.7000 - 939ms/epoch - 38ms/step
# Epoch 13/25
# 25/25 - 1s - loss: 0.6184 - accuracy: 0.6500 - val_loss: 0.5056 - val_accuracy: 0.7500 - 955ms/epoch - 38ms/step
# Epoch 14/25
# 25/25 - 1s - loss: 0.5662 - accuracy: 0.7400 - val_loss: 0.6749 - val_accuracy: 0.5500 - 939ms/epoch - 38ms/step
# Epoch 15/25
# 25/25 - 1s - loss: 0.6545 - accuracy: 0.6900 - val_loss: 0.5801 - val_accuracy: 0.7000 - 951ms/epoch - 38ms/step
# Epoch 16/25
# 25/25 - 1s - loss: 0.6246 - accuracy: 0.6500 - val_loss: 0.5183 - val_accuracy: 0.7500 - 952ms/epoch - 38ms/step
# Epoch 17/25
# 25/25 - 1s - loss: 0.5004 - accuracy: 0.7300 - val_loss: 0.5477 - val_accuracy: 0.7000 - 954ms/epoch - 38ms/step
# Epoch 18/25
# 25/25 - 1s - loss: 0.4959 - accuracy: 0.7300 - val_loss: 0.5124 - val_accuracy: 0.7500 - 972ms/epoch - 39ms/step
# Epoch 19/25
# 25/25 - 1s - loss: 0.5948 - accuracy: 0.6900 - val_loss: 0.5793 - val_accuracy: 0.6000 - 1s/epoch - 46ms/step
# Epoch 20/25
# 25/25 - 1s - loss: 0.6354 - accuracy: 0.6800 - val_loss: 0.5314 - val_accuracy: 0.7000 - 1s/epoch - 60ms/step
# Epoch 21/25
# 25/25 - 1s - loss: 0.5235 - accuracy: 0.7600 - val_loss: 0.4597 - val_accuracy: 0.8000 - 961ms/epoch - 38ms/step
# Epoch 22/25
# 25/25 - 1s - loss: 0.6016 - accuracy: 0.6700 - val_loss: 0.5466 - val_accuracy: 0.7500 - 952ms/epoch - 38ms/step
# Epoch 23/25
# 25/25 - 1s - loss: 0.5229 - accuracy: 0.7800 - val_loss: 0.4585 - val_accuracy: 0.7500 - 950ms/epoch - 38ms/step
# Epoch 24/25
# 25/25 - 1s - loss: 0.4911 - accuracy: 0.7700 - val_loss: 0.7604 - val_accuracy: 0.6000 - 941ms/epoch - 38ms/step
# Epoch 25/25
# 25/25 - 1s - loss: 0.4307 - accuracy: 0.8100 - val_loss: 0.5498 - val_accuracy: 0.7000 - 990ms/epoch - 40ms/step

# %%
import numpy as np
from google.colab import files
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))

  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  images = np.vstack([x])

  classes = model.predict(images, batch_size=10)  
  print(fn)
  if classes==1:
   print('messy')
  else:
   print('clean')
# Out:
#      <input type="file" id="files-486c7d19-5251-49b8-88b0-858ee093de94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-486c7d19-5251-49b8-88b0-858ee093de94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving messy.jpeg to messy.jpeg
# messy.jpeg
# clean

# %%
classes
# Out:
# array([[0.]], dtype=float32)
